# %%
from mnist import get_mnist_data

X_train, X_test, y_train, y_test = get_mnist_data()

# %%
from mnist import train_mnist

model = train_mnist(X_train, X_test, y_train, y_test)

# %%
from mnist import visualise_predictions
instance = X_test[13]
visualise_predictions(model, instance)
instance
